# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import csv
import html5lib
import time

# %%
current_teams = {"Anaheim_Ducks":(14),
"Arizona_Coyotes":(12),
"Boston_Bruins":(24),
"Buffalo_Sabres":(14),
"Calgary_Flames":(18),
"Carolina_Hurricanes":(9),
"Chicago_Blackhawks":(27),
"Colorado Avalanche":(9),
"Columbus_Blue_Jackets":(8),
"Dallas_Stars":(9),
"Detroit_Red_Wings":(22),
"Edmonton_Oilers":(16),
"Florida_Panthers":(13),
"Los_Angeles_Kings":(20),
"Minnesota_Wild":(6),
"Montreal_Canadiens":(29),
"Nashville_Predators":(11),
"New_Jersey_Devils":(11),
"New_York_Islanders":(15),
"New_York_Rangers":(30),
"Ottawa_Senators":(13),
"Philadelphia_Flyers":(21),
"Pittsburgh_Penguins":(19),
"San_Jose_Sharks":(12),
"St._Louis_Blues":(21),
"Tampa_Bay_Lightning":(14),
"Toronto_Maple_Leafs":(28),
"Vancouver_Canucks":(16),
"Vegas_Golden_Knights":(2),
"Washington_Capitals":(17),
"Winnipeg_Jets":(11)
                }

teams_no_space = [team.replace("_"," ") for team in current_teams.keys()]
n=0
df=pd.DataFrame(columns=["Date", "Team","Acquired","Relinquished","Notes"])

while n< 85151:
  table = None
  while isinstance(table, type(None)):
    print(n)
    page = f'insert url here/start={n}'

    table_text=[]
    page = requests.get(page)
    #time.sleep(4)
    soup = BeautifulSoup(page.text, 'html.parser')

    table = soup.find( "table", {"class":"datatable center"} )

  table_rows = table.find_all('tr')
    
  for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    table_text.append(row)
  df = df.append(table_text)
  
  n+=25
df.to_csv("Hockey_trades_0")
# Out:
# 0
# 25
# 50
# 50
# 75
# 100
# 125
# 150
# 175
# 200
# 225
# 250
# 275
# 300
# 325
# 350
# 375
# 400
# 425
# 450
# 475
# 475
# 500
# 525
# 550
# 575
# 600
# 625
# 650
# 675
# 700
# 725
# 725
# 750
# 775
# 800
# 825
# 850
# 875
# 900
# 925
# 950
# 975
# 1000
# 1025
# 1050
# 1075
# 1100
# 1125
# 1150
# 1175
# 1200
# 1225
# 1250
# 1275
# 1300
# 1325
# 1350
# 1350
# 1375
# 1400
# 1425
# 1450
# 1475
# 1500
# 1525
# 1550
# 1575
# 1600
# 1600
# 1625
# 1650
# 1675
# 1700
# 1725
# 1750
# 1775
# 1800
# 1825
# 1850
# 1875
# 1900
# 1925
# 1950
# 1975
# 2000
# 2025
# 2050
# 2075
# 2100
# 2125
# 2150
# 2175
# 2200
# 2225
# 2250
# 2275
# 2300
# 2325
# 2350
# 2375
# 2400
# 2425
# 2425
# 2450
# 2475
# 2475
# 2500
# 2525
# 2550
# 2575
# 2600
# 2600
# 2625
# 2650
# 2675
# 2700
# 2725
# 2750
# 2775
# 2800
# 2825
# 2850
# 2875
# 2900
# 2925
# 2950
# 2975
# 3000
# 3025
# 3050
# 3075
# 3100
# 3125
# 3150
# 3175
# 3200
# 3225
# 3250
# 3275
# 3300
# 3300
# 3325
# 3350
# 3375
# 3400
# 3425
# 3450
# 3475
# ...

# %%
from google.colab import files
files.download('Hockey_trades_0.csv')
